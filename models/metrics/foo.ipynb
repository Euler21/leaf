# %% [markdown]
# This notebook contains plots of various statistical and systems metrics gathered from the last run

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import visualization_utils

# %%
SHOW_WEIGHTED = True # show weighted accuracy instead of unweighted accuracy
PLOT_CLIENTS = False
stat_file = 'metrics_stat.csv' # change to None if desired
sys_file = None#'metrics_sys.csv' # change to None if desired

stat_metrics, sys_metrics = visualization_utils.load_data(stat_file, sys_file)

# %%
# Plots accuracy vs. round number.
if stat_metrics is not None:
    visualization_utils.plot_accuracy_vs_round_number(stat_metrics, True, plot_stds=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-dcea6e2082b9> in <module>
#       1 # Plots accuracy vs. round number.
#       2 if stat_metrics is not None:
# ----> 3     visualization_utils.plot_accuracy_vs_round_number(stat_metrics, True, plot_stds=False)
#
# /global/u2/a/arissa/RayLeaf/leaf/models/metrics/visualization_utils.py in plot_accuracy_vs_round_number(stat_metrics, weighted, plot_stds, figsize, title_fontsize, **kwargs)
#      80         plt.plot(accuracies[NUM_ROUND_KEY], accuracies[ACCURACY_KEY])
#      81
# ---> 82     percentile_10 = stat_metrics.groupby(NUM_ROUND_KEY, as_index=False).quantile(0.1)
#      83     percentile_90 = stat_metrics.groupby(NUM_ROUND_KEY, as_index=False).quantile(0.9)
#      84
#
# /usr/common/software/python/3.7-anaconda-2019.10/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in quantile(self, q, interpolation)
#    1912                 post_processing=post_processor,
#    1913                 q=q,
# -> 1914                 interpolation=interpolation,
#    1915             )
#    1916         else:
#
# /usr/common/software/python/3.7-anaconda-2019.10/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _get_cythonized_result(self, how, grouper, aggregate, cython_dtype, needs_values, needs_mask, needs_ngroups, result_is_index, pre_processing, post_processing, **kwargs)
#    2280                 vals = obj.values
#    2281                 if pre_processing:
# -> 2282                     vals, inferences = pre_processing(vals)
#    2283                 func = partial(func, vals)
#    2284
#
# /usr/common/software/python/3.7-anaconda-2019.10/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in pre_processor(vals)
#    1878             if is_object_dtype(vals):
#    1879                 raise TypeError(
# -> 1880                     "'quantile' cannot be performed against " "'object' dtypes!"
#    1881                 )
#    1882
#
# TypeError: 'quantile' cannot be performed against 'object' dtypes!

# %%
if PLOT_CLIENTS and stat_metrics is not None:
    visualization_utils.plot_accuracy_vs_round_number_per_client(stat_metrics, sys_metrics, max_num_clients=20)

# %%
# Plots the cumulative sum of the bytes written and read by the server in 
# the past rolling_window rounds versus the round number

if stat_metrics is not None:
    visualization_utils.plot_bytes_written_and_read(sys_metrics, rolling_window=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-ae3a4261608a> in <module>
#       3
#       4 if stat_metrics is not None:
# ----> 5     visualization_utils.plot_bytes_written_and_read(sys_metrics, rolling_window=10)
#
# /global/u2/a/arissa/RayLeaf/leaf/models/metrics/visualization_utils.py in plot_bytes_written_and_read(sys_metrics, rolling_window, figsize, title_fontsize, **kwargs)
#     180     plt.figure(figsize=figsize)
#     181
# --> 182     server_metrics = sys_metrics.groupby(NUM_ROUND_KEY, as_index=False).sum()
#     183     rounds = server_metrics[NUM_ROUND_KEY]
#     184     server_metrics = server_metrics.rolling(rolling_window, on=NUM_ROUND_KEY, min_periods=1).sum()
#
# AttributeError: 'NoneType' object has no attribute 'groupby'

# %%
visualization_utils.plot_client_computations_vs_round_number(sys_metrics, aggregate_window=1, max_num_clients=20, range_rounds=(1, 4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-2ae5d82711e0> in <module>
# ----> 1 visualization_utils.plot_client_computations_vs_round_number(sys_metrics, aggregate_window=1, max_num_clients=20, range_rounds=(1, 4))
#
# /global/u2/a/arissa/RayLeaf/leaf/models/metrics/visualization_utils.py in plot_client_computations_vs_round_number(sys_metrics, aggregate_window, max_num_clients, figsize, title_fontsize, max_name_len, range_rounds)
#     216     plt.figure(figsize=figsize)
#     217
# --> 218     num_rounds = sys_metrics[NUM_ROUND_KEY].max()
#     219     clients = sys_metrics[CLIENT_ID_KEY].unique()[:max_num_clients]
#     220
#
# TypeError: 'NoneType' object is not subscriptable

# %%
print('Longest FLOPs path: %s' % visualization_utils.get_longest_flops_path(sys_metrics))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-83209f5b3dd4> in <module>
# ----> 1 print('Longest FLOPs path: %s' % visualization_utils.get_longest_flops_path(sys_metrics))
#
# /global/u2/a/arissa/RayLeaf/leaf/models/metrics/visualization_utils.py in get_longest_flops_path(sys_metrics)
#     273     Args:
#     274         sys_metrics: pd.DataFrame as written by writer.py."""
# --> 275     num_rounds = sys_metrics[NUM_ROUND_KEY].max()
#     276     clients = sys_metrics[CLIENT_ID_KEY].unique()
#     277
#
# TypeError: 'NoneType' object is not subscriptable
